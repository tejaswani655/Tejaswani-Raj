# %%
class IITM:
    def intro():
        print('hello buddy!!')
    def say_hello():
        print('hello')
    def bye():
        print('bye')

# %%
a=int(45)
print(type(a))
# Out:
# <class 'int'>

# %%
tejas= IITM()

# %%
print(type(tejas))
# Out:
# <class '__main__.IITM'>

# %%
class Remote:
    def __init__(self):#class constructor,#magic method, #dunder method
    #initialization
        print('Object has been created with class Remote')
        print('Now you can use it!')
    def volume_up(self):
        print('vol up by 1 unit')
    def volume_down(self):
        print('vol down by 1 unit')
    def power_on(self):
        print('tv is on')
    def power_off(self):
        print('tv is off') 
    def auto_suggest_channel(self):
        import time
        print('Searching Trending Channel!!')
        time.sleep(3)
        print('YOUTUBE!! IITM')
    def __del__(self): #class destructor
        print('Object has been deleted successfully!!')

# %%
mi = Remote()
print('done')
# Out:
# Object has been created with class Remote
# Now you can use it!
# done

# %%
mi.power_on()
# Out:
# tv is on

# %%
mi.power_off()
# Out:
# tv is off

# %%
mi.volume_up()
# Out:
# vol up by 1 unit

# %%
mi.volume_down()
# Out:
# vol down by 1 unit

# %%
mi.auto_suggest_channel()
# Out:
# Searching Trending Channel!!
# YOUTUBE!! IITM

# %%
del(mi)
# Out:
# Object has been deleted successfully!!

# %%
class Car:
    def __init__(self):
        self.color='black'
        self.wheel=4
        self.spare_wheel=1
        self.airbag_support = True
        self.fuel_type = 'petrol'
        self.car_type = 'sedan'
        self.gear_type='automatic'
        print('your car is ready!')
#==================================
#Features
    def auto_park(self):
        import IPython
        url = 'https://media.tenor.com/AC-Qkr46e60AAAAM/tv-land-king-of-queens.gif'
        display(IPython.display.Image(url))
    def engine_on(self):
        import pygame
        pygame.init()
        path = r'''/Users/tejaswaniraj/Downloads/car-engine-revving-94831.mp3'''
        music = pygame.mixer.Sound(path)
        music.play()
    def speed_up(self):
        c=10
        while 10<=200:
            import time
            print(f'speed is Increasing by{c} km/hr')
            c += 10
            display(clear = True)
            time.sleep(0.5)

            if c>=100:
                print('you are crossing speed limit')
                break

    def drift_brake(self,drift = False):
        if drift ==True:
            import pygame
            pygame.init()
            path = r'''/Users/tejaswaniraj/Downloads/drift.mp3'''
            music = pygame.mixer.Sound(path)
            music.play()
            import IPython
            url = '''https://media.tenor.com/u_72T1TXSr4AAAAM/lol-mekro.gif'''
            display(IPython.display.Image(url))
        else:
            print('brake applied!!')

# %%
bmw = Car()
# Out:
# your car is ready!

# %%
bmw.drift_brake()
# Out:
# brake applied!!

# %%
bmw.speed_up()
# Out:
# you are crossing speed limit

# %%
bmw.auto_park()

# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
bmw.engine_on()

# %%
kia = Car()
# Out:
# your car is ready!

# %%
kia.color
# Out:
# 'black'

# %%
kia.gear_type
# Out:
# 'automatic'

# %%
tata = Car()
# Out:
# your car is ready!

# %%
tata.color = 'white'

# %%
kia.color
# Out:
# 'black'

# %%
tata.color
# Out:
# 'white'

# %%
maruti = Car()
# Out:
# your car is ready!

# %%
maruti.color = 'white'

# %%
class ATM:
    def __init__(self):
        print('object created')
        self.pin = 1111 # public variable
        self.balance = 3000 #public variable 

    def change_pin(self): #public method
        self.pin = input('enter new pin')
        print('your pin has been changed')

    def show_balance(self):
        print(f'''your current balance is rs {self.balance}''')

    def atm_performance_status(self):
        print('atm working 100%')

# %%
icic = ATM()
# Out:
# object created

# %%
icic.show_balance()
# Out:
# your current balance is rs 3000

# %%
icic.balance
# Out:
# 3000

# %%
icic.atm_performance_status()
# Out:
# atm working 100%

# %%
class ATM_version_1:
    def __init__(self):
        print('object created')
        self._pin = 1111 # public variable
        self._balance = 3000 #public variable 

    def change_pin(self): #public method
        self._pin = input('enter new pin')
        print('your pin has been changed')

    def show_balance(self):
        print(f'''your current balance is rs {self.balance}''')

    def atm_performance_status(self):
        print('atm working 100%')

# %%
sbi = ATM_version_1()
# Out:
# object created

# %%
sbi.atm_performance_status()
# Out:
# atm working 100%

# %%
class ATM_version_2:
    def __init__(self):
        print('object created')
        self.__pin = 1111 # public variable
        self.__balance = 3000 #public variable 

    def change_pin(self): #public method
        self.__pin = input('enter new pin')
        print('your pin has been changed')

    def show_balance(self):
        print(f'''your current balance is rs {self.balance}''')

    def __atm_performance_status(self):
        print('atm working 100%')

# %%
sbi = ATM_version_2()
# Out:
# object created

# %%
sbi._ATM_version_2__atm_performance_status()
# Out:
# atm working 100%

# %%
sbi._ATM_version_2__pin
# Out:
# 1111
